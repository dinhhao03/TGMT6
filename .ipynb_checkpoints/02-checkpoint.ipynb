# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_dir = 'C:/Users/nguye/images/01'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (612, 384)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x384>
# (800, 589)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x589>
# (800, 450)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x450>
