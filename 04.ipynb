# %%
from  PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_path = 'C:/Users/nguye/images/01/img4.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=500x310>

# %%
region = (100, 50, 175, 160)
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=75x110>

# %%
paste_position = (150, 150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=500x310>
