# %%
import numpy as np
from PIL import Image

def average_images(image_list):
    total_array = np.array(Image.open(image_list[0]), 'f')
    count=1

    for image_path in image_list[1:]:
        try:
            image_array = np.array(Image.open(image_path), 'f')
            total_array += image_array
            count=count+1
        except:
            print("Skip ", image_path);

    # Tính trung bình
    average_array = total_array / count

    # Chuyển đổi kết quả trung bình thành hình ảnh
    average_image = Image.fromarray(average_array.astype('uint8'))

    return average_image

# Sử dụng ví dụ:
my_path_1 = 'C:/Users/nguye/images/01/img1.jpg'
my_path_2 = 'C:/Users/nguye/images/01/img2.jpg'
image_list = [my_path_1, my_path_2]
result_image = average_images(image_list)
display(result_image)


# Sử dụng ví dụ:
my_path_1 = 'C:/Users/nguye/images/01/img3.jpg'
my_path_2 = 'C:/Users/nguye/images/01/img4.jpg'
image_list = [my_path_1, my_path_2]
result_image = average_images(image_list)
display(result_image)
# Out:
# Skip  C:/Users/nguye/images/01/img2.jpg
# <PIL.Image.Image image mode=RGB size=612x384>
# Skip  C:/Users/nguye/images/01/img4.jpg
# <PIL.Image.Image image mode=RGB size=800x450>
